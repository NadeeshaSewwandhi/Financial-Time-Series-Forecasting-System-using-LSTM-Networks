# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# /tmp/ipykernel_11037/2487901451.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    30.896235    33.629600    25.536997    27.579343    855215656
# 2007-10-08    29.314569    31.940442    29.130297    31.940442    126671715
# 2007-10-09    31.310854    31.587261    27.748265    29.329931    116725709
# 2007-10-10    31.602615    32.247567    31.326209    32.124718     67931378
# 2007-10-11    35.134491    36.854362    31.326209    36.854362    106320954

# %%
df.shape
# Out:
# (4208, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4208 entries, 2007-10-05 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4208 non-null   float64
#  1   (High, POWERGRID.NS)    4208 non-null   float64
#  2   (Low, POWERGRID.NS)     4208 non-null   float64
#  3   (Open, POWERGRID.NS)    4208 non-null   float64
#  4   (Volume, POWERGRID.NS)  4208 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 197.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4208.000000  4208.000000  4208.000000  4208.000000  4.208000e+03
# mean      76.086377    77.075068    75.109494    76.121539  1.188963e+07
# std       61.758299    62.480609    60.988901    61.740459  2.061999e+07
# min       18.038853    19.282911    16.172765    19.189606  0.000000e+00
# 25%       34.678071    35.225173    34.165921    34.713572  4.799653e+06
# 50%       52.692310    53.300726    51.987132    52.793474  8.344398e+06
# 75%       78.901356    79.843174    77.965768    78.922800  1.362032e+07
# max      344.843201   345.598075   337.058398   343.522120  8.552157e+08

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05    30.8962345123291  33.629599819005456
# 2       1  2007-10-08    29.3145694732666  31.940442088112835
# 3       2  2007-10-09  31.310853958129883  31.587260789940334
# 4       3  2007-10-10  31.602615356445312  32.247567370344406
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  25.536996577029846   27.57934288053112     855215656
# 2  29.130296906938245  31.940442088112835     126671715
# 3  27.748265443749254  29.329930693264668     116725709
# 4  31.326208540653212   32.12471827671269      67931378

# %%
# Candlesticks
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
                                    high = data01['High'],
                                    low = data01['Low'],
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="07b5db93-0934-4e84-ac0c-8fd8a91dca93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07b5db93-0934-4e84-ac0c-8fd8a91dca93")) {                    Plotly.newPlot(                        "07b5db93-0934-4e84-ac0c-8fd8a91dca93",                        [{"close":["POWERGRID.NS","30.8962345123291","29.3145694732666","31.310853958129883","31.602615356445312","35.134490966796875","34.90414810180664","35.364830017089844","38.97347640991211","42.01396179199219","40.539794921875","40.401588439941406","39.8641357421875","42.704986572265625","42.04468536376953","41.95253372192383","43.211734771728516","44.08702087402344","45.06979751586914","46.00653076171875","44.97767639160156","45.791534423828125","46.728240966796875","47.342491149902344","46.651466369628906","45.852962493896484","46.958587646484375","48.0795783996582","47.449981689453125","48.248497009277344","47.91065979003906","49.64588165283203","48.878089904785156","45.06979751586914","43.518856048583984","46.40578079223633","46.774322509765625","45.62262725830078","44.946956634521484","43.73383712768555","45.4229850769043","46.06794357299805","45.46907043457031","47.28104782104492","46.40578079223633","46.20615005493164","46.252220153808594","46.03722381591797","46.00653076171875","45.23871994018555","44.79340362548828","42.09075927734375","41.906471252441406","41.13865661621094","40.724056243896484","41.9679069519043","43.24243927001953","43.549560546875","43.88740158081055","44.20987319946289","45.02373504638672","44.778045654296875","46.62076950073242","46.37506866455078","45.991172790527344","44.42485046386719","43.71847915649414","42.67427062988281","43.31922912597656","43.979530334472656","42.6435661315918","41.76826095581055","42.889251708984375","40.892974853515625","33.93671798706055","30.527692794799805","33.93671798706055","34.01350402832031","35.76409149169922","36.14799118041992","35.54909896850586","33.583534240722656","31.38762664794922","32.477901458740234","34.151695251464844","35.21126937866211","34.90414810180664","33.26105499267578","32.4011116027832","30.113080978393555","29.57561683654785","29.14565086364746","31.694744110107422","32.60074234008789","32.41646957397461","32.06328582763672","31.2647762298584","31.47976303100586","31.080503463745117","31.341562271118164","31.46441650390625","33.3071174621582","34.24384307861328","33.75244903564453","32.33969497680664","31.510478973388672","32.093997955322266","30.450916290283203","30.342876434326172","32.8431510925293","32.00971984863281","27.611093521118164","29.509449005126953","28.351911544799805","28.598854064941406","28.768627166748047","29.04644203186035","30.142229080200195","29.9570255279541","30.497203826904297","30.558948516845703","30.342876434326172","30.404603958129883","30.898496627807617","30.65154457092285","30.497203826904297","30.37374496459961","29.6020565032959","29.679227828979492","30.265708923339844","30.404603958129883","30.86762237548828","30.45092010498047","31.62388801574707","32.1331901550293","32.65794372558594","32.68881607055664","31.531278610229492","31.793659210205078","31.917112350463867","32.36469650268555","32.58077621459961","32.874027252197266","32.71967315673828","32.44187927246094","31.97886085510254","31.5930118560791","31.407804489135742","31.407804489135742","31.500410079956055","31.546710968017578","31.56214714050293","31.809083938598633","31.74735450744629","31.9479923248291","31.51583480834961","30.991086959838867","30.75958824157715","29.833566665649414","30.929353713989258","31.438676834106445","30.43547248840332","29.1390323638916","28.058673858642578","27.194372177124023","27.148069381713867","26.854829788208008","26.484411239624023","26.299219131469727" ...

# %%
df = df.drop(['Date'], axis = 1)
# Out:
# /tmp/ipykernel_11037/1002300862.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price         Close         High          Low         Open       Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0         30.896235    33.629600    25.536997    27.579343    855215656
# 1         29.314569    31.940442    29.130297    31.940442    126671715
# 2         31.310854    31.587261    27.748265    29.329931    116725709
# 3         31.602615    32.247567    31.326209    32.124718     67931378
# 4         35.134491    36.854362    31.326209    36.854362    106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4203      314.707865
# 4204      314.941790
# 4205      315.170275
# 4206      315.363503
# 4207      315.495616
#
# [4208 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2945, 1)

# %%
data_testing.shape
# Out:
# (1263, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808605],
#        [0.17371828],
#        [0.20447385],
#        ...,
#        [0.90774434],
#        [0.86000354],
#        [0.87299659]])

# %%
data_training_array.shape[0]
# Out:
# 2945

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2845, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# LSTM Input -> 3D Array (batch_size, time_steps, seq_len)
# LSTM 2D OR 3D
# 2D -> (batch_sizem units)
# 3D -> (batch_size, time_steps, units)

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 33s 287ms/step - loss: 0.0343
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - loss: 0.0101
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0075
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0067
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0060
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0064
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 25s 286ms/step - loss: 0.0061
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 42s 292ms/step - loss: 0.0054
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0047
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0051
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0044
# Epoch 12/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0045
# Epoch 13/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0043
# Epoch 14/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0041
# Epoch 15/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 288ms/step - loss: 0.0038
# Epoch 16/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 0.0039
# Epoch 17/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0036
# Epoch 18/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 294ms/step - loss: 0.0039
# Epoch 19/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0031
# Epoch 20/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - loss: 0.0029
# Epoch 21/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 0.0029
# Epoch 22/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - loss: 0.0030
# Epoch 23/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - loss: 0.0028
# Epoch 24/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 0.0026
# Epoch 25/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 0.0027
# Epoch 26/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0026
# Epoch 27/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 293ms/step - loss: 0.0026
# Epoch 28/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - loss: 0.0029
# Epoch 29/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0025
# Epoch 30/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0025
# Epoch 31/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0026
# Epoch 32/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 40s 284ms/step - loss: 0.0024
# Epoch 33/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 285ms/step - loss: 0.0026
# Epoch 34/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 290ms/step - loss: 0.0024
# Epoch 35/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 291ms/step - loss: 0.0024
# Epoch 36/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0024
# Epoch 37/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - loss: 0.0024
# Epoch 38/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0022
# Epoch 39/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0023
# Epoch 40/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0024
# Epoch 41/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - loss: 0.0023
# Epoch 42/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - loss: 0.0023
# Epoch 43/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 0.0024
# Epoch 44/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0022
# Epoch 45/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 292ms/step - loss: 0.0022
# Epoch 46/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 294ms/step - loss: 0.0023
# Epoch 47/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 293ms/step - loss: 0.0023
# Epoch 48/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 41s 287ms/step - loss: 0.0023
# Epoch 49/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 288ms/step - loss: 0.0023
# Epoch 50/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 290ms/step - loss: 0.0023

# %%
past_100_days = data_training.tail(100)

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker  POWERGRID.NS
# 0          72.249084
# 1          73.721985
# 2          73.973915
# 3          73.818886
# 4          74.245255

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1263, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step

# %%
y_predicted.shape
# Out:
# (1263, 1)

# %%
scaler.scale_
# Out:
# array([0.00349382])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# model.save('stock_dl_model.h5')
model.save("stock_dl_model.keras")
